# %%
class_1 = [[('Janet',22)],['Grace',40],['Wes',50]]
print(class_1)
# Out:
# [[('Janet', 22)], ['Grace', 40], ['Wes', 50]]

# %%
for student in class_1 :
    print('You are in this class and got this grade',student)
else:
    print('You\'re not in this list')
# Out:
# You are in this class and got this grade [('Janet', 22)]
# You are in this class and got this grade ['Grace', 40]
# You are in this class and got this grade ['Wes', 50]
# You're not in this list

# %% [markdown]
# Two core objects in Pandas: DataFrame and Series

# %% [markdown]
# #### DataFrame

# %%
import pandas as pd

# %%
pd.DataFrame({'Yes':[50,21],'No':[131,2]})
# Out:
#    Yes   No
# 0   50  131
# 1   21    2

# %%
pd.DataFrame({'Bob':['I liked it.','It was awful.'], 'Sue':['Pretty good.','Bland.']})
# Out:
#              Bob           Sue
# 0    I liked it.  Pretty good.
# 1  It was awful.        Bland.

# %%
pd.DataFrame({'Bob':['I liked it.','It was awful.'],
              'Sue':['Pretty good.','Bland.']}, 
             index = ['X.0','TomTom'])
# Out:
#                   Bob           Sue
# X.0       I liked it.  Pretty good.
# TomTom  It was awful.        Bland.

# %% [markdown]
# #### Series

# %%
pd.Series([1,2,3,4])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %%
pd.Series([30,35,40],
         index = ['2015 sales','2016 sales','2017 sales'],name = 'Tomtom')
# Out:
# 2015 sales    30
# 2016 sales    35
# 2017 sales    40
# Name: Tomtom, dtype: int64

# %%
wine_data = pd.read_csv('wine-data-Thu_2_6_22.csv')

# %%
wine_data
# Out:
#         Column1   country                                        description  \
# 0             0     Italy  Aromas include tropical fruit, broom, brimston...
# 1             1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2             2        US  Tart and snappy, the flavors of lime flesh and...
# 3             3        US  Pineapple rind, lemon pith and orange blossom ...
# 4             4        US  Much like the regular bottling from 2012, this...
# ...         ...       ...                                                ...
# 129966   129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967   129967        US  Citation is given as much as a decade of bottl...
# 129968   129968    France  Well-drained gravel soil gives this wine its c...
# 129969   129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970   129970    France  Big, rich and off-dry, this is powered by inte...
#
# ...

# %%
wine_data.shape #rows are observations and columns are features
# Out:
# (129971, 14)

# %%
wine_data.head(20)
# Out:
#     Column1    country                                        description  \
# 0         0      Italy  Aromas include tropical fruit, broom, brimston...
# 1         1   Portugal  This is ripe and fruity, a wine that is smooth...
# 2         2         US  Tart and snappy, the flavors of lime flesh and...
# 3         3         US  Pineapple rind, lemon pith and orange blossom ...
# 4         4         US  Much like the regular bottling from 2012, this...
# 5         5      Spain  Blackberry and raspberry aromas show a typical...
# 6         6      Italy  Here's a bright, informal red that opens with ...
# 7         7     France  This dry and restrained wine offers spice in p...
# 8         8    Germany  Savory dried thyme notes accent sunnier flavor...
# 9         9     France  This has great depth of flavor with its fresh ...
# 10       10         US  Soft, supple plum envelopes an oaky structure ...
# 11       11     France  This is a dry wine, very spicy, with a tight, ...
# ...

# %%
wine_data.tail(50)
# Out:
#         Column1      country  \
# 129921   129921    Argentina
# 129922   129922      Austria
# 129923   129923      Germany
# 129924   129924      Germany
# 129925   129925    Argentina
# 129926   129926           US
# 129927   129927           US
# 129928   129928        Spain
# 129929   129929        Italy
# 129930   129930        Spain
# 129931   129931       France
# 129932   129932    Argentina
# 129933   129933      Austria
# 129934   129934      Austria
# 129935   129935           US
# 129936   129936       France
# 129937   129937      Austria
# 129938   129938    Argentina
# 129939   129939      Austria
# 129940   129940           US
# 129941   129941           US
# 129942   129942           US
# 129943   129943        Italy
# 129944   129944       Israel
# 129945   129945           US
# 129946   129946      Germany
# 129947   129947        Italy
# 129948   129948    Argentina
# 129949   129949           US
# 129950   129950           US
# 129951   129951       France
# ...

# %%
#Accessing a column
wine_data['country']
# Out:
# 0            Italy
# 1         Portugal
# 2               US
# 3               US
# 4               US
#             ...
# 129966     Germany
# 129967          US
# 129968      France
# 129969      France
# 129970      France
# Name: country, Length: 129971, dtype: object

# %%
wine_data['country'][14]
# Out:
# 'US'

# %% [markdown]
# #### Indexing

# %%
#I-Loc Index-based selection
wine_data.iloc[5]
# Out:
# Column1                                                                  5
# country                                                              Spain
# description              Blackberry and raspberry aromas show a typical...
# designation                                                   Ars In Vitro
# points                                                                  87
# price                                                                 15.0
# province                                                    Northern Spain
# region_1                                                           Navarra
# region_2                                                               NaN
# taster_name                                              Michael Schachner
# taster_twitter_handle                                          @wineschach
# title                    Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...
# ...

# %%
wine_data.iloc[:3,5]
# Out:
# 0     NaN
# 1    15.0
# 2    14.0
# Name: price, dtype: float64

# %%
wine_data.iloc[:,5]
# Out:
# 0          NaN
# 1         15.0
# 2         14.0
# 3         13.0
# 4         65.0
#           ...
# 129966    28.0
# 129967    75.0
# 129968    30.0
# 129969    32.0
# 129970    21.0
# Name: price, Length: 129971, dtype: float64

# %%
wine_data.iloc[5]
# Out:
# Column1                                                                  5
# country                                                              Spain
# description              Blackberry and raspberry aromas show a typical...
# designation                                                   Ars In Vitro
# points                                                                  87
# price                                                                 15.0
# province                                                    Northern Spain
# region_1                                                           Navarra
# region_2                                                               NaN
# taster_name                                              Michael Schachner
# taster_twitter_handle                                          @wineschach
# title                    Tandem 2011 Ars In Vitro Tempranillo-Merlot (N...
# ...

# %% [markdown]
# #### Loc

# %%
#Loc label based. 
wine_data.loc[5,'designation']
# Out:
# 'Ars In Vitro'

# %%
wine_data.loc[:3,'price']
# Out:
# 0     NaN
# 1    15.0
# 2    14.0
# 3    13.0
# Name: price, dtype: float64

# %% [markdown]
# #### Setting our index

# %%
#Analyzing data based on column names
wine_data.set_index('price')
# Out:
#        Column1   country                                        description  \
# price
# NaN          0     Italy  Aromas include tropical fruit, broom, brimston...
# 15.0         1  Portugal  This is ripe and fruity, a wine that is smooth...
# 14.0         2        US  Tart and snappy, the flavors of lime flesh and...
# 13.0         3        US  Pineapple rind, lemon pith and orange blossom ...
# 65.0         4        US  Much like the regular bottling from 2012, this...
# ...        ...       ...                                                ...
# 28.0    129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 75.0    129967        US  Citation is given as much as a decade of bottl...
# 30.0    129968    France  Well-drained gravel soil gives this wine its c...
# 32.0    129969    France  A dry style of Pinot Gris, this is crisp with ...
# 21.0    129970    France  Big, rich and off-dry, this is powered by inte...
#
# ...

# %% [markdown]
# ### Conditional Selection

# %%
wine_data.country == 'Italy'
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 129966    False
# 129967    False
# 129968    False
# 129969    False
# 129970    False
# Name: country, Length: 129971, dtype: bool

# %%
wine_data['country'] == 'Italy'
# Out:
# 0          True
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 129966    False
# 129967    False
# 129968    False
# 129969    False
# 129970    False
# Name: country, Length: 129971, dtype: bool

# %%
wine_data.loc[wine_data.country == 'US']
# Out:
#         Column1 country                                        description  \
# 2             2      US  Tart and snappy, the flavors of lime flesh and...
# 3             3      US  Pineapple rind, lemon pith and orange blossom ...
# 4             4      US  Much like the regular bottling from 2012, this...
# 10           10      US  Soft, supple plum envelopes an oaky structure ...
# 12           12      US  Slightly reduced, this wine offers a chalky, t...
# ...         ...     ...                                                ...
# 129945   129945      US  Hailing from one of the more popular vineyards...
# 129949   129949      US  There's no bones about the use of oak in this ...
# 129950   129950      US  This opens with herbaceous dollops of thyme an...
# 129952   129952      US  This Zinfandel from the eastern section of Nap...
# 129967   129967      US  Citation is given as much as a decade of bottl...
#
# ...

# %% [markdown]
# #### Isnull and Null

# %%
wine_data[wine_data.price.isnull()]
# Out:
#         Column1   country                                        description  \
# 0             0     Italy  Aromas include tropical fruit, broom, brimston...
# 13           13     Italy  This is dominated by oak and oak-driven aromas...
# 30           30    France  Red cherry fruit comes laced with light tannin...
# 31           31     Italy  Merlot and Nero d'Avola form the base for this...
# 32           32     Italy  Part of the extended Calanìca series, this Gri...
# ...         ...       ...                                                ...
# 129844   129844     Italy  Doga delle Clavule is a neutral, mineral-drive...
# 129860   129860  Portugal  This rich wine has a firm structure as well as...
# 129863   129863  Portugal  This mature wine that has 50% Touriga Nacional...
# 129893   129893     Italy  Aromas of passion fruit, hay and a vegetal not...
# 129964   129964    France  Initially quite muted, this wine slowly develo...
#
# ...

# %%
wine_data[wine_data.price.notnull()]
# Out:
#         Column1   country                                        description  \
# 1             1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2             2        US  Tart and snappy, the flavors of lime flesh and...
# 3             3        US  Pineapple rind, lemon pith and orange blossom ...
# 4             4        US  Much like the regular bottling from 2012, this...
# 5             5     Spain  Blackberry and raspberry aromas show a typical...
# ...         ...       ...                                                ...
# 129966   129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967   129967        US  Citation is given as much as a decade of bottl...
# 129968   129968    France  Well-drained gravel soil gives this wine its c...
# 129969   129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970   129970    France  Big, rich and off-dry, this is powered by inte...
#
# ...

# %%
wine_data[wine_data.points.notnull()]
# Out:
#         Column1   country                                        description  \
# 0             0     Italy  Aromas include tropical fruit, broom, brimston...
# 1             1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2             2        US  Tart and snappy, the flavors of lime flesh and...
# 3             3        US  Pineapple rind, lemon pith and orange blossom ...
# 4             4        US  Much like the regular bottling from 2012, this...
# ...         ...       ...                                                ...
# 129966   129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967   129967        US  Citation is given as much as a decade of bottl...
# 129968   129968    France  Well-drained gravel soil gives this wine its c...
# 129969   129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970   129970    France  Big, rich and off-dry, this is powered by inte...
#
# ...

# %% [markdown]
# #### Assigning Data

# %%
wine_data['color']=['mauve']
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-29-32b261200d98> in <module>
# ----> 1 wine_data['color']=['mauve']
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3161         else:
#    3162             # set column
# -> 3163             self._set_item(key, value)
#    3164
#    3165     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3240         """
#    3241         self._ensure_valid_index(value)
# -> 3242         value = self._sanitize_column(key, value)
#    3243         NDFrame._set_item(self, key, value)
#    3244
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3897
#    3898             # turn me into an ndarray
# ...

# %%
wine_data
# Out:
#         Column1   country                                        description  \
# 0             0     Italy  Aromas include tropical fruit, broom, brimston...
# 1             1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2             2        US  Tart and snappy, the flavors of lime flesh and...
# 3             3        US  Pineapple rind, lemon pith and orange blossom ...
# 4             4        US  Much like the regular bottling from 2012, this...
# ...         ...       ...                                                ...
# 129966   129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967   129967        US  Citation is given as much as a decade of bottl...
# 129968   129968    France  Well-drained gravel soil gives this wine its c...
# 129969   129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970   129970    France  Big, rich and off-dry, this is powered by inte...
#
# ...

# %%
#wine_data[wine_data.points.isnull()]

# %% [markdown]
# #### Summary Functions

# %%
wine_data.price.describe()
# Out:
# count    120975.000000
# mean         35.363389
# std          41.022218
# min           4.000000
# 25%          17.000000
# 50%          25.000000
# 75%          42.000000
# max        3300.000000
# Name: price, dtype: float64

# %%
wine_data.taster_name.unique() #You can use .nunique() for the number of unique elements
# Out:
# array(['Kerin O’Keefe', 'Roger Voss', 'Paul Gregutt',
#        'Alexander Peartree', 'Michael Schachner', 'Anna Lee C. Iijima',
#        'Virginie Boone', 'Matt Kettmann', nan, 'Sean P. Sullivan',
#        'Jim Gordon', 'Joe Czerwinski', 'Anne Krebiehl\xa0MW',
#        'Lauren Buzzeo', 'Mike DeSimone', 'Jeff Jenssen',
#        'Susan Kostrzewa', 'Carrie Dykes', 'Fiona Adams',
#        'Christina Pickard'], dtype=object)

# %%
wine_data.taster_name.value_counts() #Find the number of tmes a value appears in your dataset
# Out:
# Roger Voss            25514
# Michael Schachner     15134
# Kerin O’Keefe         10776
# Virginie Boone         9537
# Paul Gregutt           9532
# Matt Kettmann          6332
# Joe Czerwinski         5147
# Sean P. Sullivan       4966
# Anna Lee C. Iijima     4415
# Jim Gordon             4177
# Anne Krebiehl MW       3685
# Lauren Buzzeo          1835
# Susan Kostrzewa        1085
# Mike DeSimone           514
# Jeff Jenssen            491
# Alexander Peartree      415
# Carrie Dykes            139
# Fiona Adams              27
# Christina Pickard         6
# Name: taster_name, dtype: int64

# %% [markdown]
# #### Groupby

# %%
#groupby()
wine_data.groupby('points').price.min()
# Out:
# points
# 80      5.0
# 81      5.0
# 82      4.0
# 83      4.0
# 84      4.0
# 85      4.0
# 86      4.0
# 87      5.0
# 88      6.0
# 89      7.0
# 90      8.0
# 91      7.0
# 92     11.0
# 93     12.0
# 94     13.0
# 95     20.0
# 96     20.0
# 97     35.0
# 98     50.0
# 99     44.0
# 100    80.0
# Name: price, dtype: float64

# %%
wine_data.groupby('country').price.agg([len,min,max])
# Out:
#                             len   min     max
# country
# Argentina                3800.0   4.0   230.0
# Armenia                     2.0  14.0    15.0
# Australia                2329.0   5.0   850.0
# Austria                  3345.0   7.0  1100.0
# Bosnia and Herzegovina      2.0  12.0    13.0
# Brazil                     52.0  10.0    60.0
# Bulgaria                  141.0   8.0   100.0
# Canada                    257.0  12.0   120.0
# Chile                    4472.0   5.0   400.0
# China                       1.0  18.0    18.0
# Croatia                    73.0  12.0    65.0
# Cyprus                     11.0  11.0    21.0
# Czech Republic             12.0  15.0    45.0
# Egypt                       1.0   NaN     NaN
# England                    74.0  25.0    95.0
# France                  22093.0   5.0  3300.0
# Georgia                    86.0   9.0    40.0
# Germany                  2165.0   5.0   775.0
# Greece                    466.0   8.0    79.0
# ...

# %%
wine_data.groupby('country').price.agg([len,min,max]) #len gives you the total number of times an element appears. count gives the the number of times a specific element occurs
# Out:
#                             len   min     max
# country
# Argentina                3800.0   4.0   230.0
# Armenia                     2.0  14.0    15.0
# Australia                2329.0   5.0   850.0
# Austria                  3345.0   7.0  1100.0
# Bosnia and Herzegovina      2.0  12.0    13.0
# Brazil                     52.0  10.0    60.0
# Bulgaria                  141.0   8.0   100.0
# Canada                    257.0  12.0   120.0
# Chile                    4472.0   5.0   400.0
# China                       1.0  18.0    18.0
# Croatia                    73.0  12.0    65.0
# Cyprus                     11.0  11.0    21.0
# Czech Republic             12.0  15.0    45.0
# Egypt                       1.0   NaN     NaN
# England                    74.0  25.0    95.0
# France                  22093.0   5.0  3300.0
# Georgia                    86.0   9.0    40.0
# Germany                  2165.0   5.0   775.0
# Greece                    466.0   8.0    79.0
# ...

# %%
x = [2,3,4,4,2,2]
x.count(2)
len(x)
# Out:
# 6

# %%
countries = wine_data.groupby(['country','province']).description.agg([len])

# %%
countries
# Out:
#                              len
# country   province
# Argentina Mendoza Province  3264
#           Other              536
# Armenia   Armenia              2
# Australia Australia Other    245
#           New South Wales     85
# ...                          ...
# Uruguay   Juanico             12
#           Montevideo          11
#           Progreso            11
#           San Jose             3
#           Uruguay             24
#
# [425 rows x 1 columns]

# %%
countries.head(20)
# Out:
#                               len
# country   province
# Argentina Mendoza Province   3264
#           Other               536
# Armenia   Armenia               2
# Australia Australia Other     245
#           New South Wales      85
#           South Australia    1349
#           Tasmania             42
#           Victoria            322
#           Western Australia   286
# Austria   Austria              26
#           Burgenland          672
#           Carnuntum           103
#           Eisenberg            16
#           Kamptal             409
#           Kremstal            340
#           Leithaberg           42
#           Mittelburgenland     23
#           Neusiedlersee        13
#           Niederösterreich    600
#           Steiermark           20

# %%
mi= countries.index

# %%
mi
# Out:
# MultiIndex([('Argentina',  'Mendoza Province'),
#             ('Argentina',             'Other'),
#             (  'Armenia',           'Armenia'),
#             ('Australia',   'Australia Other'),
#             ('Australia',   'New South Wales'),
#             ('Australia',   'South Australia'),
#             ('Australia',          'Tasmania'),
#             ('Australia',          'Victoria'),
#             ('Australia', 'Western Australia'),
#             (  'Austria',           'Austria'),
#             ...
#             (       'US',        'Washington'),
#             (       'US', 'Washington-Oregon'),
#             (  'Ukraine',           'Ukraine'),
#             (  'Uruguay',         'Atlantida'),
#             (  'Uruguay',         'Canelones'),
#             (  'Uruguay',           'Juanico'),
#             (  'Uruguay',        'Montevideo'),
#             (  'Uruguay',          'Progreso'),
#             (  'Uruguay',          'San Jose'),
# ...

# %%
countries.reset_index()
# Out:
#        country          province   len
# 0    Argentina  Mendoza Province  3264
# 1    Argentina             Other   536
# 2      Armenia           Armenia     2
# 3    Australia   Australia Other   245
# 4    Australia   New South Wales    85
# ..         ...               ...   ...
# 420    Uruguay           Juanico    12
# 421    Uruguay        Montevideo    11
# 422    Uruguay          Progreso    11
# 423    Uruguay          San Jose     3
# 424    Uruguay           Uruguay    24
#
# [425 rows x 3 columns]

# %% [markdown]
# #### Sorting

# %%
countries.sort_values(by = 'len', ascending = False)
# Out:
#                                 len
# country      province
# US           California       36247
#              Washington        8639
# France       Bordeaux          5941
# Italy        Tuscany           5897
# US           Oregon            5373
# ...                             ...
# Croatia      Krk                  1
# New Zealand  Gladstone            1
# South Africa Piekenierskloof      1
# Chile        Coelemu              1
# Greece       Beotia               1
#
# [425 rows x 1 columns]

# %%
countries.sort_values(by =['country','len'])
# Out:
#                              len
# country   province
# Argentina Other              536
#           Mendoza Province  3264
# Armenia   Armenia              2
# Australia Tasmania            42
#           New South Wales     85
# ...                          ...
# Uruguay   Montevideo          11
#           Progreso            11
#           Juanico             12
#           Uruguay             24
#           Canelones           43
#
# [425 rows x 1 columns]

# %%
countries.sort_values(by =['len','country'])
# Out:
#                                     len
# country province
# Brazil  Serra do Sudeste              1
# Canada  Canada Other                  1
# Chile   Casablanca-Curicó Valley      1
#         Coelemu                       1
# China   China                         1
# ...                                 ...
# US      Oregon                     5373
# Italy   Tuscany                    5897
# France  Bordeaux                   5941
# US      Washington                 8639
#         California                36247
#
# [425 rows x 1 columns]

# %% [markdown]
# #### Dtype

# %%
wine_data.designation.dtype #where o is an object
# Out:
# dtype('O')

# %%
wine_data.dtypes
# Out:
# Column1                    int64
# country                   object
# description               object
# designation               object
# points                     int64
# price                    float64
# province                  object
# region_1                  object
# region_2                  object
# taster_name               object
# taster_twitter_handle     object
# title                     object
# variety                   object
# winery                    object
# dtype: object

# %%
wine_data.country.dtype
# Out:
# dtype('O')

# %%
pd.isnull(wine_data)
# Out:
#         Column1  country  description  designation  points  price  province  \
# 0         False    False        False        False   False   True     False
# 1         False    False        False        False   False  False     False
# 2         False    False        False         True   False  False     False
# 3         False    False        False        False   False  False     False
# 4         False    False        False        False   False  False     False
# ...         ...      ...          ...          ...     ...    ...       ...
# 129966    False    False        False        False   False  False     False
# 129967    False    False        False         True   False  False     False
# 129968    False    False        False        False   False  False     False
# 129969    False    False        False         True   False  False     False
# 129970    False    False        False        False   False  False     False
#
# ...

# %% [markdown]
# #### Rename

# %%
wine_data.rename(columns = {'points':'score'})
# Out:
#         Column1   country                                        description  \
# 0             0     Italy  Aromas include tropical fruit, broom, brimston...
# 1             1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2             2        US  Tart and snappy, the flavors of lime flesh and...
# 3             3        US  Pineapple rind, lemon pith and orange blossom ...
# 4             4        US  Much like the regular bottling from 2012, this...
# ...         ...       ...                                                ...
# 129966   129966   Germany  Notes of honeysuckle and cantaloupe sweeten th...
# 129967   129967        US  Citation is given as much as a decade of bottl...
# 129968   129968    France  Well-drained gravel soil gives this wine its c...
# 129969   129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970   129970    France  Big, rich and off-dry, this is powered by inte...
#
# ...

# %%
wine_data.rename(index = {0:'firstEntry'})
# Out:
#             Column1   country  \
# firstEntry        0     Italy
# 1                 1  Portugal
# 2                 2        US
# 3                 3        US
# 4                 4        US
# ...             ...       ...
# 129966       129966   Germany
# 129967       129967        US
# 129968       129968    France
# 129969       129969    France
# 129970       129970    France
#
#                                                   description  \
# firstEntry  Aromas include tropical fruit, broom, brimston...
# 1           This is ripe and fruity, a wine that is smooth...
# 2           Tart and snappy, the flavors of lime flesh and...
# 3           Pineapple rind, lemon pith and orange blossom ...
# 4           Much like the regular bottling from 2012, this...
# ...                                                       ...
# 129966      Notes of honeysuckle and cantaloupe sweeten th...
# 129967      Citation is given as much as a decade of bottl...
# ...
